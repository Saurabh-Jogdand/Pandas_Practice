# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    858     52   John
# 1  2023-01-02       B   West    179     42   Mary
# 2  2023-01-03       C  North    101     93    Bob
# 3  2023-01-04       D  South    649     93  Alice
# 4  2023-01-05       A   East    640     63   John
# 5  2023-01-06       B   West    513     70   Mary
# 6  2023-01-07       C  North    815     27    Bob
# 7  2023-01-08       D  South    389     24  Alice
# 8  2023-01-09       A   East    576     11   John
# 9  2023-01-10       B   West    447     68   Mary
# 10 2023-01-11       C  North    418     49    Bob
# 11 2023-01-12       D  South    108     69  Alice
# 12 2023-01-13       A   East    260     41   John
# 13 2023-01-14       B   West    861     20   Mary
# 14 2023-01-15       C  North    370     12    Bob
# 15 2023-01-16       D  South    166     55  Alice
# 16 2023-01-17       A   East    891     58   John
# 17 2023-01-18       B   West    304     95   Mary
# 18 2023-01-19       C  North    976     95    Bob
# 19 2023-01-20       D  South    445     38  Alice

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region',columns = "Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     640.0    NaN    NaN    NaN
# North      NaN    NaN  418.0    NaN
# South      NaN    NaN    NaN  389.0
# West       NaN  447.0    NaN    NaN

# %%
pd.pivot_table(df,values = ['Sales','Units'],index = 'Region',columns = "Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     645.0    NaN    NaN    NaN  45.0   NaN   NaN   NaN
# North      NaN    NaN  536.0    NaN   NaN   NaN  55.2   NaN
# South      NaN    NaN    NaN  351.4   NaN   NaN   NaN  55.8
# West       NaN  460.8    NaN    NaN   NaN  59.0   NaN   NaN

# %% [markdown]
# __Cross Table__

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
